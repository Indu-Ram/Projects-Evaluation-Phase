# %% [markdown]
#                                                Baseball Case Study

# %% [markdown]
# ![baseball-155990_640.webp](attachment:baseball-155990_640.webp)

# %% [markdown]
# Project Description

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# Input features

# %% [markdown]
# -- Input features-
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %% [markdown]
# -- Output: Number of predicted wins (W)
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
# For downloading the dataset, use the link given below.
# -- Output: Number of predicted wins (W)
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
# For downloading the dataset, use the link given below.

# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# Uploading the data set

# %%
Base=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")

# %% [markdown]
# Lets check the first five rows of Base data set

# %%
Base.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# Lets check the last five rows of Base data set

# %%
Base.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %% [markdown]
# Lets check the shape of Base data set

# %%
Base.shape
# Out:
# (30, 17)

# %% [markdown]
# Lets check the missing values in base data set

# %%
Base.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no missing values in Base data set.

# %% [markdown]
# lets check the data type of Base data set.

# %%
Base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# Base Data set has int data type except the ERA coloum has float data type.

# %% [markdown]
# Lets check the duplicate value in data set.

# %% [markdown]
# Base.duplicated().sum()

# %% [markdown]
# There is no duplicate value in the data set.

# %% [markdown]
# Lets check the unique value in the Base data set.

# %%
Base.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# Lets check the Descriptive Statistics

# %%
Base.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
Base.describe().T
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ER    30.0   635.833333   70.140786   478.00   587.2500   644.500   679.25
# ERA   30.0     3.956333    0.454089     2.94     3.6825     4.025     4.22
# CG    30.0     3.466667    2.763473     0.00     1.0000     3.000     5.75
# SHO   30.0    11.300000    4.120177     4.00     9.0000    12.000    13.00
# SV    30.0    43.066667    7.869335    28.00    37.2500    42.000    46.75
# E     30.0    94.333333   13.958889    75.00    86.0000    91.000    96.75
#
#          max
# W     100.00
# R     891.00
# AB   5649.00
# H    1515.00
# 2B    308.00
# 3B     49.00
# HR    232.00
# BB    570.00
# SO   1518.00
# SB    134.00
# RA    844.00
# ER    799.00
# ERA     5.04
# CG     11.00
# SHO    21.00
# SV     62.00
# E     126.00

# %%
Base.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# Data Visualisation

# %%
plt.figure(figsize=[10,6])
sns.heatmap(Base.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# It confirms no null values in the data set.

# %% [markdown]
#  Distribution of the target variable (number of wins)

# %% [markdown]
# Total Values in the target variable

# %%
Base['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(Base['W'], kde=True)
plt.xlabel('Number of Wins')
plt.title('Distribution of Wins')
plt.show()

# %% [markdown]
# Minimum win is 63 and Maximum is 100.
# Between 68-86 has highest wins.

# %% [markdown]
# Correlation heatmap to visualize the relationships between features and targe

# %%
correlation_matrix=Base.corr()
plt.figure(figsize=(12,10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Box plot to visualize the distribution of wins for each categorical feature

# %%
for feature in categorical_features:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=feature, y='W', data=Base) 
    plt.xlabel(feature)
    plt.ylabel('Number of Wins')
    plt.title(f'Wins vs {feature}')
    plt.show()

# %%
Base.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Normal Distribution Curve

# %%
plt.figure(figsize=(15,15))
plotnumber=1
for column in Base:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(Base[column])
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# No skewness is present in these columns 'W','ERA','BB','2B'and '3B.'

# %% [markdown]
# Multivariate analysis

# %%
sns.pairplot(Base, hue='W')

# %%
sns.pairplot(Base)
plt.show()

# %% [markdown]
# Lets check the correlation

# %%
Base.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %% [markdown]
# Correlation with heatmap

# %%
plt.figure(figsize=(20,10))
sns.heatmap(Base.corr(),annot=True, linewidth=0.5, linecolor='black', fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
from scipy.stats import zscore
z = np.abs(zscore(Base))
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
base_new = Base[(z<3).all(axis = 1)]
base_new.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# Checking the shape of new and old data set.

# %%
base_new.shape
# Out:
# (29, 17)

# %%
Base.shape
# Out:
# (30, 17)

# %% [markdown]
# Total data loss is one data point.

# %%
base_new.plot(kind ='box', subplots =True , layout =(3,6), figsize = (15,20), )
# Out:
# W         AxesSubplot(0.125,0.657941;0.110714x0.222059)
# R      AxesSubplot(0.257857,0.657941;0.110714x0.222059)
# AB     AxesSubplot(0.390714,0.657941;0.110714x0.222059)
# H      AxesSubplot(0.523571,0.657941;0.110714x0.222059)
# 2B     AxesSubplot(0.656429,0.657941;0.110714x0.222059)
# 3B     AxesSubplot(0.789286,0.657941;0.110714x0.222059)
# HR        AxesSubplot(0.125,0.391471;0.110714x0.222059)
# BB     AxesSubplot(0.257857,0.391471;0.110714x0.222059)
# SO     AxesSubplot(0.390714,0.391471;0.110714x0.222059)
# SB     AxesSubplot(0.523571,0.391471;0.110714x0.222059)
# RA     AxesSubplot(0.656429,0.391471;0.110714x0.222059)
# ER     AxesSubplot(0.789286,0.391471;0.110714x0.222059)
# ERA          AxesSubplot(0.125,0.125;0.110714x0.222059)
# CG        AxesSubplot(0.257857,0.125;0.110714x0.222059)
# SHO       AxesSubplot(0.390714,0.125;0.110714x0.222059)
# SV        AxesSubplot(0.523571,0.125;0.110714x0.222059)
# E         AxesSubplot(0.656429,0.125;0.110714x0.222059)
# dtype: object

# %% [markdown]
# Mainly outiers are present in Errors columns. But after removing outliers by Z score method it is seen that still there is some outliers in errors column. As the dataset is not big (30 rows), let's keep the remaining part as the deletation made the loss of data which means the loss of informations.

# %% [markdown]
# Checking Skewness:

# %%
base_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# The standard range for skewness is between -0.5 to 0.5.
# Hits, Shutouts, Saves, Complete_Games snd Errors are positively skewed in nature, need to transform.

# %% [markdown]
# Let's transform all the positive skewed data using boxcox transformation:

# %%
base2= base_new.copy()
base2.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
from sklearn.preprocessing import PowerTransformer
scaler= PowerTransformer(method= 'yeo-johnson')

features=['H', 'SHO', 'SV', 'CG','E']
base2[features]= scaler.fit_transform(base2[features].values)
base2[features].head()
# Out:
#      H       SHO        SV        CG         E
# 0  0.0 -0.787002  1.532753 -0.307098 -0.348265
# 1  0.0  0.236737  0.312020 -0.307098 -0.540820
# 2  0.0 -0.252844 -0.664137  2.011315 -1.326125
# 3  0.0 -0.513555 -0.820689  1.264463  0.650818
# 4  0.0  0.236737 -1.149165  1.264463 -0.540820

# %%
plt.figure(figsize=(10,8),facecolor='green')
plno=1
for x in base2[features]:
    if plno<=5:
        plt.subplot(2,3,plno)
        sns.distplot(base2[x])
        plt.xlabel (x, fontsize=15)
    plno +=1
plt.tight_layout()

# %% [markdown]
# Skewness after transforming skewed features

# %%
base2.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.000000
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# All skewness are removed from the whole dataset.

# %% [markdown]
# Check Multicollinearity problem

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif= pd.DataFrame()
vif["VIF"]= [variance_inflation_factor(base2,i)for i in range(base2.shape[1])]
vif["Features"] = base2.columns
vif
# Out:
#              VIF Features
# 0    1110.344704        W
# 1    1942.635540        R
# 2    3727.698538       AB
# 3            NaN        H
# 4    1036.598788       2B
# 5      35.506943       3B
# 6     204.331372       HR
# 7     253.481295       BB
# 8     416.468908       SO
# 9      25.770130       SB
# 10  18139.464950       RA
# 11  53592.828752       ER
# 12  24049.925033      ERA
# 13      3.388033       CG
# 14      3.311748      SHO
# 15      8.911602       SV
# 16      1.791588        E

# %% [markdown]
# There is a huge VIF Values in many cases. For Earned_Runs it is 53592.82 !!!!

# %% [markdown]
# Let's do Features selection

# %% [markdown]
# Feature Selection Using PCA:
# Data Standarization:

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

#seperate Features(x) and Lable(y)
x=base2.drop(columns=['W'])
y=base2['W']

#data standarization
x_scale= scaler.fit_transform(x)

# %%
from sklearn.decomposition import PCA
pca = PCA()

#plot the graph to find the principal components

x_pca = pca.fit_transform(x_scale)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Components No', fontsize= 16)
plt.ylabel('Variance percentage', fontsize= 16)
plt.grid()
plt.show()

# %% [markdown]
# For components= 10, the variance percentage is >0.95 i.e. greater than 95%.
#
# Let's keep top 10 features for model evaluation

# %%
pca_new = PCA(n_components=10)
x_scale_new = pca_new.fit_transform(x_scale)
x_scale_final= pd.DataFrame(x_scale_new)

# %%
x_scale_final.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.334674 -1.941662 -2.676364 -0.530757 -2.687106  0.250135  0.754136
# 1  0.244426  0.096931 -0.379591  0.015748 -0.470853  0.583660 -1.042088
# 2 -1.319690 -0.513412 -0.193672  2.773065 -1.012409 -0.346124  1.341699
# 3  0.955247  1.330627 -0.464798  0.745588  0.378492 -1.235915 -0.123902
# 4  2.880733 -1.349175  0.419041  1.714457  0.072905  0.227692 -1.136708
#
#           7         8         9
# 0 -0.196817  0.737180 -0.350598
# 1 -1.079991  0.039167 -0.318376
# 2 -0.808746  0.116500  1.159568
# 3  0.201159  0.547284  0.849772
# 4 -0.560509 -1.006888  0.167333

# %% [markdown]
# check VIF after feature selection:

# %%
vif_final= pd.DataFrame()
vif_final['VIF']= [variance_inflation_factor(x_scale_final.values,i) for i in range(x_scale_final.shape[1])]
vif_final['Top 10 Features']= x_scale_final.columns
vif_final
# Out:
#    VIF  Top 10 Features
# 0  1.0                0
# 1  1.0                1
# 2  1.0                2
# 3  1.0                3
# 4  1.0                4
# 5  1.0                5
# 6  1.0                6
# 7  1.0                7
# 8  1.0                8
# 9  1.0                9

# %% [markdown]
# Final predictions using different Regression ML Models:
# Find best Random state:

# %%
from sklearn.linear_model import LinearRegression

r2_max=0
random_max=0
for i in range(1,2000):
    x_train,x_test,y_train,y_test = train_test_split(x_scale_final,y,test_size = 0.25, random_state=i)
    lin_reg= LinearRegression()
    
    lin_reg.fit(x_train,y_train)
    y_pred=lin_reg.predict(x_test)
    r2 = r2_score(y_test,y_pred)
    
    if r2>r2_max:
        r2_max=r2
        random_max=i
print('Best accuracy is', r2_max ,'on Random_state', random_max)
# Out:
# Best accuracy is 0.9785570625845031 on Random_state 1585

# %%
print('Training feature shape:',x_train.shape)
print('Training target shape:',y_train.shape)
print('Test feature shape:',x_test.shape)
print('Test target shape:',y_test.shape)
# Out:
# Training feature shape: (21, 10)
# Training target shape: (21,)
# Test feature shape: (8, 10)
# Test target shape: (8,)

# %% [markdown]
# For random state=1585, the accuracy score is best. Lets take this random state for further steps.

# %% [markdown]
# Using LinearRegression()

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scale_final,y,test_size = 0.25, random_state=1585)

lin_reg= LinearRegression()

lin_reg.fit(x_train, y_train)

y_pred = lin_reg.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.9785570625845031
# Mean absolute error: 1.5435284922603634
# Mean square error: 2.8301326929484647
# Root mean square error: 1.6822998225490202

# %% [markdown]
# Using GridSearchCV:

# %%
from sklearn.model_selection import GridSearchCV

grid = dict(fit_intercept=['True', 'False'], n_jobs=[1,-1])

grid_lin = GridSearchCV(estimator=lin_reg, param_grid= grid, cv=9)

grid_lin.fit(x_train, y_train)
grid_lin.best_params_
# Out:
# {'fit_intercept': 'True', 'n_jobs': 1}

# %%
grid_lin_best = LinearRegression(fit_intercept= 'True', n_jobs= 1)

grid_lin_best.fit(x_train, y_train)
y_pred = grid_lin_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.9785570625845031
# Mean absolute error: 1.5435284922603634
# Mean square error: 2.8301326929484647
# Root mean square error: 1.6822998225490202

# %% [markdown]
# No such improvement seen after GridSearchCV.

# %% [markdown]
# Using DecisionTreeRegressor():

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)

y_pred = dt.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.3152598555700249
# Mean absolute error: 7.375
# Mean square error: 90.375
# Root mean square error: 9.506576670915772

# %% [markdown]
# Using GridSearchCV:

# %%
param = {'criterion' : ["squared_error", "friedman_mse", "absolute_error"],
    'max_depth' : range(15,30),
    'min_samples_split' : range(1,4),
    'splitter' : ["best", "random"],
    'min_samples_leaf' : range(1,4)}

grid_search = GridSearchCV(estimator = dt,cv=9,param_grid = param)
grid_search.fit(x_train, y_train)

print("Best Parameters:" , grid_search.best_params_)
# Out:
# Best Parameters: {'criterion': 'squared_error', 'max_depth': 22, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}

# %%
grid_dt_best = grid_search.best_estimator_
grid_dt_best.fit(x_train, y_train)

y_pred = grid_dt_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.4854978098733278
# Mean absolute error: 5.4375
# Mean square error: 67.90625
# Root mean square error: 8.240524861924754

# %% [markdown]
# After using Grid seaech CV, R2 is negative. When the chosen model does not follow the trend of the data and fits worse, then the r2 score becomes negetive. So here we just reject DecisionTreeRegressor() for our model building.

# %% [markdown]
# Using KNeighborsRegressor():

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn import neighbors
rmse_val = []
for i in range(0, 8):
    i = i+1
    knn = neighbors.KNeighborsRegressor(n_neighbors = i)

    knn.fit(x_train,y_train) 
    y_pred=knn.predict(x_test) 
    error =np. sqrt(mean_squared_error(y_test,y_pred)) 
    rmse_val.append(error) 
    print('RMSE value for k= ' , i , 'is:', error)
# Out:
# RMSE value for k=  1 is: 8.803408430829505
# RMSE value for k=  2 is: 8.364732512160804
# RMSE value for k=  3 is: 6.379219736334879
# RMSE value for k=  4 is: 6.031169040907409
# RMSE value for k=  5 is: 6.2257529665093525
# RMSE value for k=  6 is: 5.865092118249769
# RMSE value for k=  7 is: 6.065543366140465
# RMSE value for k=  8 is: 6.474710418234935

# %%
min(rmse_val)
# Out:
# 5.865092118249769

# %% [markdown]
# For k=4 we get the best RMSE value for KNeighborsRegressor()

# %%
knn =KNeighborsRegressor(n_neighbors= 4)
knn.fit(x_train, y_train)

y_pred = knn.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.7243991949804665
# Mean absolute error: 5.1875
# Mean square error: 36.375
# Root mean square error: 6.031169040907409

# %% [markdown]
# Using GridSearchCV

# %%
param = {'algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute'],
             'leaf_size' : [30,40,25,34,10,15,22], 'n_jobs':[1,-1],
             'n_neighbors' : [4],'weights': ['uniform', 'distance'], 'p':[1,2,3]}
    

gridsearchknn = GridSearchCV(estimator = knn, param_grid=param, cv=5)

gridsearchknn.fit(x_train, y_train) 

print("Best Parameters:" , gridsearchknn.best_params_)
# Out:
# Best Parameters: {'algorithm': 'auto', 'leaf_size': 30, 'n_jobs': 1, 'n_neighbors': 4, 'p': 1, 'weights': 'uniform'}

# %%
grid_knn_best = gridsearchknn.best_estimator_

grid_knn_best.fit(x_train, y_train)

y_pred = grid_knn_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.6227062862554753
# Mean absolute error: 5.9375
# Mean square error: 49.796875
# Root mean square error: 7.056690088136222

# %% [markdown]
# Nothing is improved after GridSearchCV.

# %% [markdown]
# Using RandomForestRegressor():

# %%
from sklearn.ensemble import RandomForestRegressor

rf= RandomForestRegressor()
rf.fit(x_train, y_train)

y_pred = rf.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.7169629927785013
# Mean absolute error: 5.16375
# Mean square error: 37.3564625
# Root mean square error: 6.111993332784322

# %% [markdown]
# Using GridSearchCV:

# %%
params = {'n_estimators' : [100,110,80], 'criterion' : ["squared_error", "absolute_error"], 
          'min_samples_split' : [3,2,1], 'n_jobs': [1,-1], 'min_samples_leaf' : [1,2,3]}

rf_grd = GridSearchCV(rf, param_grid = params)
rf_grd.fit(x_train, y_train)
print('best params : ', rf_grd.best_params_)
# Out:
# best params :  {'criterion': 'squared_error', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'n_jobs': 1}

# %%
grid_rf_best = rf_grd.best_estimator_

grid_rf_best.fit(x_train, y_train)

y_pred = grid_rf_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.6948781101922431
# Mean absolute error: 5.322289814352327
# Mean square error: 40.27132192509566
# Root mean square error: 6.345968950845542

# %% [markdown]
# r2 score, RMSE slightly improved after GridSearchCV.

# %% [markdown]
# Using Support Vector Regression():

# %%
from sklearn.svm import SVR
svr_rbf = SVR(kernel='rbf')
svr_rbf.fit(x_train, y_train)

y_pred = svr_rbf.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.1645947107848269
# Mean absolute error: 8.49010528544482
# Mean square error: 110.26044496875886

# %%
from sklearn.svm import SVR
svr_poly = SVR(kernel='poly')
svr_poly.fit(x_train, y_train)

y_pred = svr_poly.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.43412328683243895
# Mean absolute error: 7.2673145127647825
# Mean square error: 74.68688431447481

# %%
from sklearn.svm import SVR
svr_lin = SVR(kernel='linear')
svr_lin.fit(x_train, y_train)

y_pred = svr_lin.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.9763617026965032
# Mean absolute error: 1.5693061871085234
# Mean square error: 3.1198858956662097

# %% [markdown]
# Using GridSearchCV:

# %%
params = {'gamma':['scale', 'auto'],'C':[1.0,10,10, 0.5,0.1,0.001], 'tol':[0.01,0.001,0.002,0.0001], 'kernel':['linear']}

svr_grd = GridSearchCV(svr_lin, param_grid = params, cv= 7)
svr_grd.fit(x_train, y_train)
print('best params : ', svr_grd.best_params_)
# Out:
# best params :  {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear', 'tol': 0.001}

# %%
grid_svr_best = svr_grd.best_estimator_
grid_svr_best.fit(x_train, y_train)

y_pred = grid_svr_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.6945966618836077
# Mean absolute error: 5.1716464435976395
# Mean square error: 40.30846870420572
# Root mean square error: 6.348895077429279

# %% [markdown]
# r2 score, RMSE are not improved after GridSearchCV.

# %% [markdown]
# Using GradientBoostingRegressor()

# %%
from sklearn.ensemble import  GradientBoostingRegressor

gbdt= GradientBoostingRegressor()
gbdt.fit(x_train, y_train)

y_pred = gbdt.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.7966841542675607
# Mean absolute error: 4.456067749016373
# Mean square error: 26.834514826592414
# Root mean square error: 5.180204129818864

# %% [markdown]
# Using GridSearchCV:

# %%
params = {'loss': ['squared_error', 'absolute_error', 'huber', 'quantile'], 'n_estimators':[100,150,80],
          'criterion':['friedman_mse', 'squared_error', 'mse'], 'min_samples_leaf':range(1,5),
         'max_features': ['auto', 'sqrt', 'log2']}

gbdt_grd = GridSearchCV(gbdt, param_grid = params, cv=5)
gbdt_grd.fit(x_train, y_train)
print('best params : ', gbdt_grd.best_params_)
# Out:
# best params :  {'criterion': 'mse', 'loss': 'absolute_error', 'max_features': 'auto', 'min_samples_leaf': 2, 'n_estimators': 80}

# %%
grid_gbdt_best = gbdt_grd.best_estimator_

grid_gbdt_best.fit(x_train, y_train)

y_pred = grid_gbdt_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.6565626702489238
# Mean absolute error: 5.79173518649303
# Mean square error: 45.328361318864694
# Root mean square error: 6.732634055023687

# %% [markdown]
# r2 score, RMSE are improved after GridSearchCV.

# %% [markdown]
# Using AdaBoostRegressor():

# %%
from sklearn.ensemble import AdaBoostRegressor

ada= AdaBoostRegressor()
ada.fit(x_train, y_train)

y_pred = ada.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.7422877824031233
# Mean absolute error: 4.5723214285714295
# Mean square error: 34.01398596938776
# Root mean square error: 5.8321510585192975

# %% [markdown]
# Using GridSearchCV:

# %%
params = { 'loss' : ['linear', 'square'], 'learning_rate': [0.1,0.001,1,0.5] ,
        'n_estimators':[50,90,40] }

ada_grd = GridSearchCV(ada, param_grid = params, cv=5)
ada_grd.fit(x_train, y_train)
print('best params : ', ada_grd.best_params_)
# Out:
# best params :  {'learning_rate': 0.5, 'loss': 'square', 'n_estimators': 40}

# %%
grid_ada_best = ada_grd.best_estimator_

grid_ada_best.fit(x_train, y_train)

y_pred = grid_ada_best.predict(x_test)

print('R2 Score:', r2_score(y_test, y_pred))
print('Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('Mean square error:', mean_squared_error(y_test, y_pred))
print('Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.7860416571032343
# Mean absolute error: 4.752976190476192
# Mean square error: 28.239158163265316
# Root mean square error: 5.314052894285615

# %% [markdown]
# r2 score, RMSE are not improved after GridSearchCV.

# %% [markdown]
# As per 7 different regression model we can see that the model with maximum R2 score and minimum RMSE value is LinearRegression().
# Let's check the cross validation score before final prediction.

# %% [markdown]
# Cross Validation:

# %%
from sklearn.model_selection import cross_val_score

all_models = [lin_reg , dt , knn , grid_rf_best , svr_lin , grid_gbdt_best, ada]

for i in all_models:
    cvscore = cross_val_score(i, x_scale,y, cv = 5)
    print('Cross Validation Score of :',i)
    print("\n Cross Validation Score : " ,cvscore)
    print("\nMean CV Score :",cvscore.mean())
    print("\nStd deviation :",cvscore.std())
    print("\n-----------")
    print("-----------")
# Out:
# Cross Validation Score of : LinearRegression()
#
#  Cross Validation Score :  [ 0.74130456 -0.37452157  0.64150719  0.35961076 -0.28509109]
#
# Mean CV Score : 0.21656196853905296
#
# Std deviation : 0.46420506848369186
#
# -----------
# -----------
# Cross Validation Score of : DecisionTreeRegressor()
#
#  Cross Validation Score :  [-1.74431818 -9.03947368  0.04726056  0.1        -0.62146226]
#
# Mean CV Score : -2.2515987139489377
#
# Std deviation : 3.458459063513975
#
# -----------
# -----------
# Cross Validation Score of : KNeighborsRegressor(n_neighbors=4)
#
#  Cross Validation Score :  [-0.1337358  -0.71463816  0.45263488  0.4602459   0.76267689]
#
# Mean CV Score : 0.16543674317710524
#
# Std deviation : 0.527281146767567
#
# -----------
# -----------
# Cross Validation Score of : RandomForestRegressor(min_samples_leaf=3, n_jobs=1)
#
#  Cross Validation Score :  [ 0.3448257  -4.25397683  0.42483646  0.40884539  0.87281745]
#
# Mean CV Score : -0.4405303673449833
#
# Std deviation : 1.9159509113632167
#
# -----------
# -----------
# Cross Validation Score of : SVR(kernel='linear')
#
#  Cross Validation Score :  [ 0.62819138 -0.81723259  0.82175565  0.88138641  0.86677639]
#
# Mean CV Score : 0.4761754462102131
#
# Std deviation : 0.6530243322685754
#
# -----------
# -----------
# Cross Validation Score of : GradientBoostingRegressor(criterion='mse', loss='absolute_error',
#                           max_features='auto', min_samples_leaf=2,
#                           n_estimators=80)
#
#  Cross Validation Score :  [ 0.42049982 -5.45340682  0.63652184  0.5321196   0.88560391]
#
# Mean CV Score : -0.5957323287541938
#
# Std deviation : 2.4337044440098636
#
# -----------
# -----------
# Cross Validation Score of : AdaBoostRegressor()
#
#  Cross Validation Score :  [ 0.27909468 -7.88229532  0.53396998  0.40179101  0.90589695]
#
# Mean CV Score : -1.1523085399362463
#
# Std deviation : 3.371545870003068
#
# -----------
# -----------

# %% [markdown]
# Checking overfitting problem:

# %%
from sklearn.linear_model import Ridge, Lasso, RidgeCV, LassoCV
#LASSO Regression

lassocv= LassoCV()
lassocv.fit(x_train, y_train)
alpha= lassocv.alpha_   #best learning rate for LASSO
alpha
# Out:
# 2.363401596123994

# %%
lasso_reg=Lasso(alpha)
lasso_reg.fit(x_train,y_train)
print ("Score after applying LASSO regression on the model is :", lasso_reg.score(x_test, y_test))
# Out:
# Score after applying LASSO regression on the model is : 0.8785781260302389

# %%
#RIDGE Regression

ridgecv= RidgeCV(alphas=np.arange(0.0001, 1.0, 0.001),  normalize= True, cv=10 )
ridgecv.fit(x_train, y_train)
alpha= ridgecv.alpha_   #best learning rate for RIDGE
alpha
# Out:
# 0.41709999999999997

# %%
ridge_reg=Ridge(alpha)
ridge_reg.fit(x_train,y_train)
print ("Score after applying LASSO regression on the model is :", ridge_reg.score(x_test, y_test))
# Out:
# Score after applying LASSO regression on the model is : 0.9815171000762242

# %% [markdown]
# After using LASSO() and Ridge(), there is no large change in score. So this model is not OVERFITTED.

# %% [markdown]
# Conclusion:
# Our final model is Linear Regression() for this particular dataset

# %% [markdown]
# Final Model:

# %%
y_pred = lin_reg.predict(x_test)
y_pred
# Out:
# array([ 85.79609315,  79.16289702,  61.61119698, 102.02630912,
#         83.33202514,  93.50779331,  68.27214835,  72.81204713])

# %%
# Let's visualize the variation of actual test data and predicted data
plt.figure(figsize=(10,7))
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Sales", fontsize= 15)
plt.ylabel("Predicted Sales",fontsize= 15)
plt.title("Actual & Predicted Sales" , fontsize= 15, fontweight= 'bold')
plt.show()

# %%
print('Final R2 Score:', r2_score(y_test, y_pred))
print('\nFinal Mean absolute error:', mean_absolute_error(y_test, y_pred))
print('\nFinal Mean square error:', mean_squared_error(y_test, y_pred))
print('\nFinal Root mean square error:',np.sqrt( mean_squared_error(y_test, y_pred)))
# Out:
# Final R2 Score: 0.9785570625845031
#
# Final Mean absolute error: 1.5435284922603634
#
# Final Mean square error: 2.8301326929484647
#
# Final Root mean square error: 1.6822998225490202

# %% [markdown]
# Coefficient:

# %%
coefficient= lin_reg.coef_
coefficient
# Out:
# array([-4.0388897 , -2.32772542, -0.44798542, -1.17172084, -1.84352587,
#        -0.39252684, -0.52037717, -1.26281548,  1.55012143, -3.50024548])

# %% [markdown]
# Load and save the model
# Now , let's save the model for future use.

# %%
import pickle
pickle.dump(lin_reg, open("Baseball_Prediction_model", "wb"))
load_Baseball_Prediction_model= pickle.load(open("Baseball_Prediction_model", "rb"))

# %%
y_pred = load_Baseball_Prediction_model.predict(x_test)

y_test = np.array(y_test)
data_prediction_by_model = pd.DataFrame()
data_prediction_by_model["Predicted Values"] = y_pred
data_prediction_by_model["Actual Values"] = y_test
data_prediction_by_model.sample(n=6)
# Out:
#    Predicted Values  Actual Values
# 4         83.332025             83
# 7         72.812047             74
# 6         68.272148             67
# 5         93.507793             92
# 3        102.026309            100
# 1         79.162897             81
